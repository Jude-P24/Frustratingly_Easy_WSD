# %%
import pandas as pd

# %%
df = pd.read_csv('sentences_final.csv')

# %%
df
# Out:
#             pmid                                           sentence  \
# 0       32063488  AAD requires life-long substitutive therapy wi...
# 1       32063488  The lowest possible HC dose must be identified...
# 2       32063488  Patients must be educated to double-triple HC ...
# 3       33527139  Modified-Release Hydrocortisone in Congenital ...
# 4       37830561  Hydrocortisone Mitigates Alzheimer's-Related C...
# ...          ...                                                ...
# 190116   6290359  Today we differentiate four hepatic forms: acu...
# 190117   8368699  Severe hepatic porphyrias (acute intermittent ...
# 190118   8701527  The porphyric attack was characterized by exce...
# 190119   6308821  The second situation is cutaneous involvement ...
# 190120   1589138  The increase in urinary coproporphyrins, with ...
#
#                                           masked_sentence abbreviation  \
# 0       AAD requires life-long substitutive therapy wi...           HC
# ...
